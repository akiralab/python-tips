# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# usage: subplot(nrows, ncols, index)
plt.subplot(211)
plt.subplot(212)

# %%
# usage: subplots(nrows, ncols)
plt.subplots(3, 3)
# Out:
# (<Figure size 432x288 with 9 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcf13dcfac8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf13f27940>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf13fc9e48>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x7fcf13ffa518>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf14021be0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf14054278>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x7fcf1407b908>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf140a4f98>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf140d6668>]],
#        dtype=object))

# %%
fig, a = plt.subplots(2, 2)
x = np.arange(1, 5)
a[0][0].plot(x, x*x)
a[0][0].set_title('square')
# Out:
# Text(0.5,1,'square')

# %%
fig, a = plt.subplots(2, 2)
x = np.arange(1, 10)
a[0][0].plot(x, x*x)
a[0][0].set_title('square')
a[0][1].plot(x, np.exp(x))
a[0][1].set_title('exp')
a[1][0].plot(x, np.log10(x))
a[1][0].set_title('log')
a[1][1].plot(x, np.sqrt(x))
a[1][1].set_title('sqrt')
# Out:
# Text(0.5,1,'sqrt')

# %%
# subplot2grid(shape, location, rowspan, colspan)
fig1 = plt.subplot2grid((3, 3), (0, 0), colspan=2)
fig2 = plt.subplot2grid((3, 3), (0, 2), rowspan = 3)
fig3 = plt.subplot2grid((3, 3), (1, 0), rowspan=2, colspan=2)

# %%
# subplot2grid + tight_layout()

fig1 = plt.subplot2grid((3, 3), (0, 0), colspan=2)
fig2 = plt.subplot2grid((3, 3), (0, 2), rowspan = 3)
fig3 = plt.subplot2grid((3, 3), (1, 0), rowspan=2, colspan=2)
plt.tight_layout()
