# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# np.random.random() -> [0, 1]の乱数を返す
print(np.random.random())

a = []
for i in range(1000):
    a.append(np.random.random())
a.sort()

plt.plot(a)
# Out:
# 0.010466861936220817

# %%
# np.random.randn() -> 標準正規分布に従った乱数を返す
print(np.random.randn())

b = []
for i in range(1000):
    b.append(np.random.randn())
b.sort()

plt.plot(b)
# Out:
# -1.17813348370884

# %%
# 配列にしたい場合はnp.random.rand(rows, cols)
print(np.random.rand(2,4))

print(np.random.randn(2,4))
# Out:
# [[0.04573551 0.50055376 0.22890722 0.84766662]
#  [0.49078765 0.73022675 0.76745943 0.1374161 ]]
# [[ 1.24840727  1.19158913 -0.23567141  1.04197038]
#  [-1.06600955 -0.44303284 -1.20106041  0.69167662]]
